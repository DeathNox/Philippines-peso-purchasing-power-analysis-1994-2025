# %%
import pandas as pd

# %%
csv = pd.read_excel("datas/Statistical Tables on June 2025 CPI for All Income Households.xlsx")

# %%
table_18 = pd.read_excel("datas/Statistical Tables on June 2025 CPI for All Income Households.xlsx", sheet_name="table 18", skiprows=2)

table_18.head()
# Out:
#   (2018=100) Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN         NaN        NaN         NaN        NaN
# 1       Year      Month         NaN        NaN         NaN        NaN
# 2        NaN        Jan         NaN        Feb         NaN        Mar
# 3        NaN        NaN         NaN        NaN         NaN        NaN
# 4       1994       3.09         NaN       3.05         NaN       3.06
#
#    Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  ...  Unnamed: 16 Unnamed: 17  \
# 0         NaN        NaN         NaN        NaN  ...          NaN         NaN
# 1         NaN        NaN         NaN        NaN  ...          NaN         NaN
# 2         NaN        Apr         NaN        May  ...          NaN         Sep
# 3         NaN        NaN         NaN        NaN  ...          NaN         NaN
# 4         NaN       3.05         NaN       3.03  ...          NaN        2.97
#
# ...

# %%
# Save table_18 DataFrame to a CSV file
table_18.to_csv("table_18.csv", index=False)

# %%
table_18
# Out:
#                                            (2018=100) Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN        NaN         NaN
# 1                                                Year      Month         NaN
# 2                                                 NaN        Jan         NaN
# 3                                                 NaN        NaN         NaN
# 4                                                1994       3.09         NaN
# 5                                                1995       2.91         NaN
# 6                                                1996       2.66         NaN
# 7                                                1997       2.52         NaN
# 8                                                1998       2.37         NaN
# 9                                                1999       2.14         NaN
# 10                                               2000       2.03         NaN
# ...

# %%
table_18 = pd.read_excel("datas/Statistical Tables on June 2025 CPI for All Income Households.xlsx", sheet_name="table 18", skiprows=3)

# %%
table_18
# Out:
#                                            Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0                                                Year      Month         NaN
# 1                                                 NaN        Jan         NaN
# 2                                                 NaN        NaN         NaN
# 3                                                1994       3.09         NaN
# 4                                                1995       2.91         NaN
# 5                                                1996       2.66         NaN
# 6                                                1997       2.52         NaN
# 7                                                1998       2.37         NaN
# 8                                                1999       2.14         NaN
# 9                                                2000       2.03         NaN
# 10                                               2001       1.91         NaN
# ...

# %%
threshold = len(table_18) * 0.5  # 50% threshold
table_18 = table_18.dropna(axis=1, thresh=threshold)

table_18
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 3  \
# 0                                                Year      Month        NaN
# 1                                                 NaN        Jan        Feb
# 2                                                 NaN        NaN        NaN
# 3                                                1994       3.09       3.05
# 4                                                1995       2.91       2.89
# 5                                                1996       2.66       2.64
# 6                                                1997       2.52       2.51
# 7                                                1998       2.37       2.33
# 8                                                1999       2.14       2.13
# 9                                                2000       2.03       2.02
# 10                                               2001       1.91       1.91
# ...

# %%
print(table_18.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7',
#        'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13', 'Unnamed: 15',
#        'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23',
#        'Unnamed: 25'],
#       dtype='object')

# %%
table_18
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 3  \
# 0                                                Year      Month        NaN
# 1                                                 NaN        Jan        Feb
# 2                                                 NaN        NaN        NaN
# 3                                                1994       3.09       3.05
# 4                                                1995       2.91       2.89
# 5                                                1996       2.66       2.64
# 6                                                1997       2.52       2.51
# 7                                                1998       2.37       2.33
# 8                                                1999       2.14       2.13
# 9                                                2000       2.03       2.02
# 10                                               2001       1.91       1.91
# ...

# %%
# Example: Assign a new list of column names

table_18.columns = ["Year", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Ave"]

print(table_18.columns)
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'Ave'],
#       dtype='object')

# %%
table_18
# Out:
#                                                  Year    Jan   Feb   Mar  \
# 0                                                Year  Month   NaN   NaN
# 1                                                 NaN    Jan   Feb   Mar
# 2                                                 NaN    NaN   NaN   NaN
# 3                                                1994   3.09  3.05  3.06
# 4                                                1995   2.91  2.89  2.88
# 5                                                1996   2.66  2.64  2.64
# 6                                                1997   2.52  2.51   2.5
# 7                                                1998   2.37  2.33  2.31
# 8                                                1999   2.14  2.13  2.14
# 9                                                2000   2.03  2.02  2.02
# 10                                               2001   1.91  1.91  1.91
# 11                                               2002   1.85  1.86  1.85
# ...

# %%
table_18 = table_18.iloc[3:].reset_index(drop=True)

# %%
table_18 = table_18.drop("Ave", axis=1)

# %%
table_18.to_csv("table_18_cleaned.csv", index=False)

table_18
# Out:
#                                                  Year   Jan   Feb   Mar   Apr  \
# 0                                                1994  3.09  3.05  3.06  3.05
# 1                                                1995  2.91  2.89  2.88  2.87
# 2                                                1996  2.66  2.64  2.64  2.63
# 3                                                1997  2.52  2.51   2.5   2.5
# 4                                                1998  2.37  2.33  2.31   2.3
# 5                                                1999  2.14  2.13  2.14  2.14
# 6                                                2000  2.03  2.02  2.02  2.02
# 7                                                2001  1.91  1.91  1.91  1.91
# 8                                                2002  1.85  1.86  1.85  1.85
# 9                                                2003  1.82  1.81  1.81  1.81
# 10                                               2004  1.77  1.76  1.76  1.75
# ...

# %%
table_18 = table_18.iloc[:-3].reset_index(drop=True)

# %%
table_18.to_csv("table_18_cleaned.csv", index=False)

# %%
table_18
# Out:
#     Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0   1994  3.09  3.05  3.06  3.05  3.03  3.02     3  2.98  2.97  2.97  2.97
# 1   1995  2.91  2.89  2.88  2.87  2.86  2.84  2.82  2.79  2.75  2.74  2.74
# 2   1996  2.66  2.64  2.64  2.63  2.62   2.6   2.6  2.58  2.58  2.57  2.57
# 3   1997  2.52  2.51   2.5   2.5  2.49  2.47  2.46  2.45  2.44  2.43  2.41
# 4   1998  2.37  2.33  2.31   2.3  2.27  2.24  2.23  2.22  2.21  2.21  2.18
# 5   1999  2.14  2.13  2.14  2.14  2.14  2.13  2.12  2.12  2.11   2.1   2.1
# 6   2000  2.03  2.02  2.02  2.02  2.01     2  1.99  1.98  1.98  1.97  1.94
# 7   2001  1.91  1.91  1.91  1.91  1.91  1.89  1.88  1.88  1.87  1.87  1.87
# 8   2002  1.85  1.86  1.85  1.85  1.85  1.84  1.83  1.83  1.83  1.83  1.83
# 9   2003  1.82  1.81  1.81  1.81  1.81  1.79  1.79  1.79  1.79  1.79  1.78
# 10  2004  1.77  1.76  1.76  1.75  1.74  1.72   1.7  1.69  1.68  1.68  1.67
# ...

# %%
import pandas as pd
import plotly.graph_objects as go

# Load your CSV
# ...existing code...
df = pd.read_csv("datas/merged_output_w_price.csv")
df2 = pd.read_csv("datas/RicePriceHistory_Retail.csv")

df.rename(columns={'Rice Price': 'Rice Price - Farmgate'}, inplace=True)

# Merge df2's rice price column into df based on 'Year'
df = df.merge(df2[['Year', 'Rice Price - Regular']], on='Year', how='left')

# Now df has a new 'Rice Price' column from df2
df.head()
# ...existing code...

df.to_csv('merged_output_w_price.csv', index=False)
